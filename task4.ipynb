# %% [markdown]
# # Task 4 :Prediction using Decision Tree Algorithm
#
# Description :Create the Decision Tree classifier and visualize it graphically.
#
# The purpose is if we feed any new data to this classifier, it would be able to
# predict the right class accordingly.
#
#
#
#
# DONE BY: PROMOTH N

# %%
#importing required libraries
import numpy as np
import pandas as pd
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.model_selection import train_test_split
from sklearn import metrics
import matplotlib.pyplot as plt

# %%
#importing dataset
path="E:\Downloads\Iris.csv"
iris_df=pd.read_csv(path)
iris_df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
iris_df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
#checking if there are Ny null values in the dataset to clean the data
iris_df.isna().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
iris_df.drop('Id',axis=1,inplace=True)

# %%
import seaborn as sns 
plt.figure (figsize=(6,10), dpi= 100, facecolor='w')
sns.pairplot(iris_df,  hue = "Species")

# %%
#forming train test dataset
train,test=train_test_split(iris_df,test_size=0.3)
print(train.shape)
print(test.shape)
# Out:
# (105, 5)
# (45, 5)

# %%
train_X = train[['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm']]# taking the training data features
train_y=train.Species# output of our training data
test_X= test[['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm']] # taking test data features
test_y =test.Species   #output value of test data

# %% [markdown]
# ###  define the Decision Tree Algorithm

# %%
#Defining decision tree algorithm
dtree=DecisionTreeClassifier(max_depth=3,random_state=1)
model_all_params=DecisionTreeClassifier().fit(train_X,train_y)

print("The Decision Tree Classifier created")
# Out:
# The Decision Tree Classifier created

# %%
#prediction
prediction=model_all_params.predict(test_X)

# %%
#taking an example to seee prediction
X=[[5.3,2.5,1.3,0.3]]
pre=model_all_params.predict(X)
print(pre)
# Out:
# ['Iris-setosa']

# %%
#Accuracy 
print('The accuracy of decision tree is',"{:.3f}".format(metrics.accuracy_score(prediction,test_y)))
# Out:
# The accuracy of decision tree is 0.933

# %% [markdown]
# Model is 95.6% accurate

# %%
cn=iris_df.Species
fn=['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm']

# %%
plt.figure(figsize = (50,40))

plot_tree(model_all_params,feature_names=fn,class_names = cn,filled = True)
# Out:
# [Text(1395.0, 1956.96, 'PetalLengthCm <= 2.6\ngini = 0.662\nsamples = 105\nvalue = [31, 33, 41]\nclass = Iris-setosa'),
#  Text(1046.25, 1522.0800000000002, 'gini = 0.0\nsamples = 31\nvalue = [31, 0, 0]\nclass = Iris-setosa'),
#  Text(1743.75, 1522.0800000000002, 'PetalWidthCm <= 1.75\ngini = 0.494\nsamples = 74\nvalue = [0, 33, 41]\nclass = Iris-setosa'),
#  Text(1395.0, 1087.2, 'PetalLengthCm <= 4.95\ngini = 0.193\nsamples = 37\nvalue = [0, 33, 4]\nclass = Iris-setosa'),
#  Text(697.5, 652.3200000000002, 'SepalLengthCm <= 4.95\ngini = 0.061\nsamples = 32\nvalue = [0, 31, 1]\nclass = Iris-setosa'),
#  Text(348.75, 217.44000000000005, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]\nclass = Iris-setosa'),
#  Text(1046.25, 217.44000000000005, 'gini = 0.0\nsamples = 31\nvalue = [0, 31, 0]\nclass = Iris-setosa'),
#  Text(2092.5, 652.3200000000002, 'PetalWidthCm <= 1.55\ngini = 0.48\nsamples = 5\nvalue = [0, 2, 3]\nclass = Iris-setosa'),
#  Text(1743.75, 217.44000000000005, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3]\nclass = Iris-setosa'),
#  Text(2441.25, 217.44000000000005, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0]\nclass = Iris-setosa'),
#  Text(2092.5, 1087.2, 'gini = 0.0\nsamples = 37\nvalue = [0, 0, 37]\nclass = Iris-setosa')]

# %% [markdown]
# # Thank you!!#
